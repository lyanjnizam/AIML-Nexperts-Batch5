# %% [markdown]
# # Evaluation Metrics
# -

# %% [markdown]
# Regression:
# 1. MAE
# 2. MSE
# 3. RMSE
# 4. R2 Score

# %% [markdown]
# Classification:
# 1. Accuracy
# 2. Precision
# 3. Recall
# 4. F1 Score
# - Confusion Matrix

# %% [markdown]
# 1. Accuracy:
#
# $${Accuracy = } \frac{CorrectPredictions} {TotalPredictions}$$
